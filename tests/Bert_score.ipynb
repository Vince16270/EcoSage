# %% [markdown]
# # Blue Scores
#
# In eerste instantie hebben we het model geëvalueerd met klassieke metriek zoals:
#
# - Exact Match (EM): geeft alleen een score van 1 als het modelantwoord exact gelijk is aan de referentie. In ons geval was deze 0%.
#
# - Word Overlap: gemiddeld slechts 28.76%, wat suggereert dat het model vaak andere woorden gebruikte dan in de referenties.
#
# - BLEU: een populaire metriek in machinevertaling, maar de score was gemiddeld 0.48%, wat erg laag is.
#
# - ROUGE-1 (F1): had een gemiddelde van slechts 6.55%, wat wijst op beperkte n-gram overlap.
#
# Deze scores gaven ons het signaal dat het model misschien inhoudelijk goed was, maar niet in exact dezelfde bewoordingen als de referentie.
#
# BERTScore biedt een alternatief dat semantiek begrijpt, in plaats van puur naar woord-overlap te kijken. Het gebruikt de werking van BERT (een voorgetraind taalmodel van Google) om te meten hoe semantisch gelijk twee zinnen zijn.
#
# ### Voordelen van BERTScore:
#
# 1. Begrijpt de betekenis achter verschillende woorden.
#
# 2. Houdt rekening met synoniemen en parafrases.
#
# 3. Past goed bij open vragen of natuurlijke taal antwoorden.
#
#
# ### Wat doen we in dit deel?
# We berekenen de BERT F1-score tussen het modelantwoord en elk van de 5 referenties afzonderlijk. Daarna pakken we de hoogste score per rij, en berekenen daar het gemiddelde van voor een beter algemeen beeld van de prestaties.
#
# Zo kunnen we eerlijker beoordelen hoe goed het model inhoudelijk antwoord geeft, los van exacte bewoording.

# %%
import csv
import os
import pandas as pd

df = pd.read_csv(r"C:\Users\Nima\OneDrive - Reza Company\Desktop\Nima+\School\Datalab-V\tests\evaluation_results\evaluation_csv.csv")

# %%
df
# Out:
#     id                                           question  \
# 0    1  What is the European Green Deal and what are i...
# 1    2  How does the 'Fit for 55' package contribute t...
# 2    3  What are the key principles of the EU's strate...
# 3    4      How can I reduce my carbon footprint at home?
# 4    5  What are some simple ways to save energy in my...
# 5    6  What is the role of renewable energy sources i...
# 6    7  How does the European Green Deal aim to make t...
# 7    8  What is the 'Farm to Fork' strategy and how do...
# 8    9        How can I contribute to a circular economy?
# 9   12  What are some examples of sustainable living p...
# 10  13  What is the importance of biodiversity and how...
# 11  14                 How can I reduce my plastic waste?
# 12  15  What is the Just Transition Mechanism and who ...
# 13  16  How does the EU promote the use of renewable h...
# 14  19  What is the energy performance of buildings di...
# 15  21  What are the environmental impacts of fast fas...
# 16  23         What are some tips for sustainable travel?
# 17  24  How does the European Green Deal address air a...
# 18  25  What is the role of citizens in achieving the ...
# 19  28  What is the EU's strategy for sustainable and ...
#
#                                          model_answer  \
# 0   The European Green Deal is a comprehensive str...
# 1   The 'Fit for 55' package is a set of proposals...
# 2   Key principles of the EU's strategy for clean ...
# 3   1. Use energy-efficient appliances and light b...
# 4   Some simple ways to save energy in daily life ...
# 5   Renewable energy sources play a crucial role i...
# 6   The European Green Deal aims to make transport...
# 7   The 'Farm to Fork' strategy is a European Unio...
# 8   You can contribute to a circular economy by:\r...
# 9   Mention at least 3 examples and explain why th...
# 10  Provide a few key points on the importance of ...
# 11  There are several ways to reduce plastic waste...
# 12  The Just Transition Mechanism (JTM) is a finan...
# 13  The EU promotes the use of renewable hydrogen ...
# 14  The Energy Performance of Buildings Directive ...
# 15  Include at least 3 key points:\r\n1. Fast fash...
# 16  1. Choose eco-friendly transportation: Opt for...
# 17  The European Green Deal is a comprehensive str...
# 18  Sorry, I couldn't generate an answer. Here are...
# 19  The EU's strategy for sustainable and smart mo...
#
#                                           reference_1  \
# 0   The European Green Deal is the EU's master pla...
# 1   ‘Fit for 55’ is the EU’s 2021 legislative mega...
# 2   The strategy follows the ‘energy-efficiency-fi...
# 3   Upgrade your insulation and windows so your he...
# 4   Take shorter, cooler showers and install low-f...
# 5   Renewables displace fossil fuels, cutting CO₂ ...
# 6   EU funds rail, metro and bus projects to make ...
# 7   Targets a 50 % reduction in chemical pesticide...
# 8   Choose products with eco-design or repairabili...
# 9   Adopt a plant-forward diet, limiting red meat ...
# 10  Biodiversity underpins ecosystem services such...
# 11  Opt for refill shops where you bring your own ...
# 12  It channels grants, loans and guarantees to co...
# 13  The EU aims for 10 Mt of domestic renewable hy...
# 14  You must receive an Energy Performance Certifi...
# 15  Fast fashion uses large volumes of water for d...
# 16  Choose rail over short-haul flights; Europe’s ...
# 17  Revises Ambient Air Quality Directives to alig...
# 18  Consumers drive demand for sustainable product...
# 19  Targets a 90 % cut in transport emissions by 2...
#
#                                           reference_2  \
# 0   It is a roadmap covering energy, transport, in...
# 1   It tightens the Emissions Trading System, exte...
# 2   It aims to massively scale renewables, targeti...
# 3   Switch to a certified green electricity tariff...
# 4   Air-dry clothes and dishes instead of using el...
# 5   Because wind and solar costs have fallen, they...
# 6   It phases in stricter CO₂ limits so only zero-...
# 7   Aims to boost EU organic farming share to 25 %...
# 8   Lease or rent items such as tools or electroni...
# 9   Carry a reusable water bottle, coffee cup and ...
# 10  The EU plans to legally protect 30 % of land a...
# 11  Buy toiletries like shampoo bars instead of bo...
# 12  Workers receive up-skilling and re-skilling pr...
# 13  It funds electrolysers through the Important P...
# 14  Member states have to set minimum energy-perfo...
# 15  Cheap synthetic garments shed micro-plastics d...
# 16  Pack light to cut aircraft fuel burn and save ...
# 17  Introduces a Zero Pollution Action Plan aiming...
# 18  Voting in local, national and EU elections hel...
# 19  Plans to double high-speed rail traffic by 203...
#
#                                           reference_3  \
# 0   Under the Deal, every EU policy must contribut...
# 1   The package raises the Renewable Energy Direct...
# 2   Grid modernisation and digitalisation are cent...
# 3   Choose A+++-rated appliances and run them only...
# 4   Use lids on pots and match burner sizes to coo...
# 5   They diversify the energy mix, improving secur...
# 6   Alternative-fuels infrastructure regulation wi...
# 7   Sets measures to improve animal welfare, inclu...
# 8   Share or swap rarely used goods within neighbo...
# 9   Buy second-hand goods, repair broken items and...
# 10  Restoration targets will revive 25 000 km of f...
# 11  Use beeswax wraps or reusable silicone covers ...
# 12  A dedicated Just Transition Fund of over €19 b...
# 13  Guarantee-of-origin certificates will prove th...
# 14  All new buildings must be zero-emission from 2...
# 15  Rapid turnover encourages over-consumption, cr...
# 16  Stay in eco-labelled accommodation that follow...
# 17  Strengthens urban wastewater rules to capture ...
# 18  Public-consultation feedback shapes EU regulat...
# 19  Proposes zero-emission urban logistics and car...
#
#                                           reference_4  \
# 0   A key aim is to slash emissions at least 55 % ...
# 1   By upgrading everything from fuel taxation to ...
# 2   Affordability and security of supply remain co...
# 3   Lower your thermostat by 1-2 °C and use progra...
# 4   Enable power-saving modes and unplug chargers ...
# 5   Deploying renewables creates local jobs in man...
# 6   The ReFuelEU and FuelEU proposals oblige aviat...
# 7   Encourages shorter supply chains and fairer re...
# 8   Return used products to take-back schemes so m...
# 9   Collect rainwater for gardening and install lo...
# 10  The strategy tightens rules against illegal lo...
# 11  Choose glass, metal or paper packaging over pl...
# 12  The Public Sector Loan Facility offers concess...
# 13  The TEN-E revision supports dedicated hydrogen...
# 14  Building-renovation passports will guide owner...
# 15  Buying timeless, quality pieces and mending cl...
# 16  Respect fragile ecosystems by sticking to mark...
# 17  Promotes precision farming and nutrient-manage...
# 18  Participating in citizen assemblies or climate...
# 19  Digital traffic management and multimodal tick...
#
#                                           reference_5  bleu_1  bleu_2  ...  \
# 0   The package also seeks to mobilise €1 trillion...     9.0     0.9  ...
# 1   Taken together, these new and updated laws loc...     4.0     0.3  ...
# 2   Empowering citizens—through smart meters, pros...     0.3     0.5  ...
# 3   Cut waste: repair instead of replace, recycle ...     0.3     0.6  ...
# 4   Let natural daylight in and switch to motion-s...     0.1     0.6  ...
# 5   Decentralised renewables empower communities t...     0.8     0.9  ...
# 6   Urban mobility plans encourage walking and cyc...     0.5     0.2  ...
# 7   Seeks to halve per-capita food waste at retail...     0.7     0.5  ...
# 8   Compost organic waste to cycle nutrients back ...     0.2     0.2  ...
# 9   Use renewable tariffs and switch off standby p...     0.2     0.2  ...
# 10  Agro-ecological practices and nature-based sol...     0.4     3.3  ...
# 11  Participate in local clean-up events and lobby...     0.4     0.7  ...
# 12  Technical assistance helps local authorities d...     0.1     0.1  ...
# 13  State-aid rules have been relaxed so governmen...     1.4     0.4  ...
# 14  Renovations must include EV-charging readiness...     0.3     0.3  ...
# 15  Choosing certified organic cotton or recycled ...     0.5     0.0  ...
# 16  Offset unavoidable emissions through certified...     0.1     0.1  ...
# 17  Invests in industrial decarbonisation to slash...     0.2     0.3  ...
# 18  Grassroots activism, from school strikes to co...     0.1     0.2  ...
# 19  Promotes automation and connectivity to improv...     0.2     0.2  ...
#
#     rouge1_f1_2  rouge1_f1_3  rouge1_f1_4  rouge1_f1_5  bertscore_f1  \
# 0          10.4         23.8         18.6         10.4      0.695411
# 1          13.2          8.3         11.4          6.6      0.662858
# 2          11.4          2.4          9.2          3.5      0.522448
# 3           8.5          4.3         12.4         10.6      0.536837
# 4           5.7          5.6          3.4          5.6      0.531289
# 5          11.3         15.9          6.5          6.5      0.552980
# 6           6.0          6.1          6.0          6.2      0.529699
# 7           7.2          9.1          5.5         10.8      0.529644
# 8           2.0          0.0          4.0          3.0      0.415053
# 9           7.3          3.0          1.5          5.9      0.488722
# 10         20.0          5.0          5.1          5.1      0.600564
# 11          8.8         11.4         11.6          2.9      0.535133
# 12          3.4          4.9          2.5          1.7      0.498561
# 13          6.9          7.0          4.2          1.4      0.532612
# 14          6.5          4.3          2.2          0.0      0.524445
# 15          0.0          2.0          9.6          6.1      0.509618
# 16          2.9          3.9          3.8          0.0      0.491184
# 17          8.6          3.8          5.6          5.5      0.542792
# 18          5.5          2.3          2.2          2.2      0.396752
# 19          4.1          1.4          1.4          4.2      0.513907
#
#     bertscore_ref1  bertscore_ref2  bertscore_ref3  bertscore_ref4  \
# 0         0.695411        0.545027        0.591295        0.602468
# 1         0.662858        0.537642        0.530465        0.565504
# 2         0.429814        0.517700        0.439663        0.522448
# 3         0.501377        0.536837        0.418191        0.488502
# 4         0.454937        0.531289        0.467365        0.500149
# 5         0.536290        0.529222        0.552979        0.478439
# 6         0.528174        0.474826        0.497339        0.510225
# 7         0.512044        0.485557        0.528032        0.517278
# 8         0.415053        0.392595        0.367306        0.398094
# 9         0.488722        0.451123        0.453870        0.441951
# 10        0.478792        0.600564        0.478161        0.467168
# 11        0.502472        0.512258        0.520218        0.535134
# 12        0.498561        0.450330        0.448615        0.467683
# 13        0.532612        0.459781        0.464519        0.500892
# 14        0.461955        0.524445        0.439909        0.465343
# 15        0.495523        0.459857        0.460156        0.509618
# 16        0.413936        0.455232        0.491184        0.477085
# 17        0.489381        0.542792        0.478437        0.534290
# 18        0.362570        0.396752        0.386719        0.370682
# 19        0.448330        0.426409        0.480633        0.451011
#
#     bertscore_ref5
# 0         0.548973
# 1         0.474317
# 2         0.431097
# 3         0.523224
# 4         0.440154
# 5         0.476010
# 6         0.529699
# 7         0.529644
# 8         0.388449
# 9         0.486575
# 10        0.474727
# 11        0.421335
# 12        0.436589
# 13        0.447678
# 14        0.449513
# 15        0.496130
# 16        0.453591
# 17        0.458097
# 18        0.360406
# 19        0.513907
#
# [20 rows x 34 columns]

# %%
import pandas as pd
from bert_score import score
from transformers import AutoTokenizer, AutoModelForMaskedLM
import numpy as np

# 🧠 Laad jouw model/tokenizer
model_name = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForMaskedLM.from_pretrained(model_name)


def compute_all_bertscores(row):
    model_answer = row["model_answer"]
    
    for i in range(1, 6):
        ref = row.get(f"reference_{i}", None)
        if pd.notna(ref):
            F1 = score(
                [model_answer],
                [ref],
                model_type=model_name,
                lang="en",
                verbose=False,
                rescale_with_baseline=False
            )[2]
            row[f"bertscore_ref{i}"] = F1[0].item()
        else:
            row[f"bertscore_ref{i}"] = np.nan
    
    return row

# Pas toe op elke rij
df = df.apply(compute_all_bertscores, axis=1)
df
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#     id                                           question  \
# 0    1  What is the European Green Deal and what are i...
# 1    2  How does the 'Fit for 55' package contribute t...
# 2    3  What are the key principles of the EU's strate...
# 3    4      How can I reduce my carbon footprint at home?
# 4    5  What are some simple ways to save energy in my...
# 5    6  What is the role of renewable energy sources i...
# 6    7  How does the European Green Deal aim to make t...
# 7    8  What is the 'Farm to Fork' strategy and how do...
# 8    9        How can I contribute to a circular economy?
# 9   12  What are some examples of sustainable living p...
# 10  13  What is the importance of biodiversity and how...
# 11  14                 How can I reduce my plastic waste?
# 12  15  What is the Just Transition Mechanism and who ...
# 13  16  How does the EU promote the use of renewable h...
# 14  19  What is the energy performance of buildings di...
# 15  21  What are the environmental impacts of fast fas...
# 16  23         What are some tips for sustainable travel?
# 17  24  How does the European Green Deal address air a...
# 18  25  What is the role of citizens in achieving the ...
# 19  28  What is the EU's strategy for sustainable and ...
#
#                                          model_answer  \
# 0   The European Green Deal is a comprehensive str...
# 1   The 'Fit for 55' package is a set of proposals...
# 2   Key principles of the EU's strategy for clean ...
# 3   1. Use energy-efficient appliances and light b...
# 4   Some simple ways to save energy in daily life ...
# 5   Renewable energy sources play a crucial role i...
# 6   The European Green Deal aims to make transport...
# 7   The 'Farm to Fork' strategy is a European Unio...
# 8   You can contribute to a circular economy by:\r...
# 9   Mention at least 3 examples and explain why th...
# 10  Provide a few key points on the importance of ...
# 11  There are several ways to reduce plastic waste...
# 12  The Just Transition Mechanism (JTM) is a finan...
# 13  The EU promotes the use of renewable hydrogen ...
# 14  The Energy Performance of Buildings Directive ...
# 15  Include at least 3 key points:\r\n1. Fast fash...
# 16  1. Choose eco-friendly transportation: Opt for...
# 17  The European Green Deal is a comprehensive str...
# 18  Sorry, I couldn't generate an answer. Here are...
# 19  The EU's strategy for sustainable and smart mo...
#
#                                           reference_1  \
# 0   The European Green Deal is the EU's master pla...
# 1   ‘Fit for 55’ is the EU’s 2021 legislative mega...
# 2   The strategy follows the ‘energy-efficiency-fi...
# 3   Upgrade your insulation and windows so your he...
# 4   Take shorter, cooler showers and install low-f...
# 5   Renewables displace fossil fuels, cutting CO₂ ...
# 6   EU funds rail, metro and bus projects to make ...
# 7   Targets a 50 % reduction in chemical pesticide...
# 8   Choose products with eco-design or repairabili...
# 9   Adopt a plant-forward diet, limiting red meat ...
# 10  Biodiversity underpins ecosystem services such...
# 11  Opt for refill shops where you bring your own ...
# 12  It channels grants, loans and guarantees to co...
# 13  The EU aims for 10 Mt of domestic renewable hy...
# 14  You must receive an Energy Performance Certifi...
# 15  Fast fashion uses large volumes of water for d...
# 16  Choose rail over short-haul flights; Europe’s ...
# 17  Revises Ambient Air Quality Directives to alig...
# 18  Consumers drive demand for sustainable product...
# 19  Targets a 90 % cut in transport emissions by 2...
#
#                                           reference_2  \
# 0   It is a roadmap covering energy, transport, in...
# 1   It tightens the Emissions Trading System, exte...
# 2   It aims to massively scale renewables, targeti...
# 3   Switch to a certified green electricity tariff...
# 4   Air-dry clothes and dishes instead of using el...
# 5   Because wind and solar costs have fallen, they...
# 6   It phases in stricter CO₂ limits so only zero-...
# 7   Aims to boost EU organic farming share to 25 %...
# 8   Lease or rent items such as tools or electroni...
# 9   Carry a reusable water bottle, coffee cup and ...
# 10  The EU plans to legally protect 30 % of land a...
# 11  Buy toiletries like shampoo bars instead of bo...
# 12  Workers receive up-skilling and re-skilling pr...
# 13  It funds electrolysers through the Important P...
# 14  Member states have to set minimum energy-perfo...
# 15  Cheap synthetic garments shed micro-plastics d...
# 16  Pack light to cut aircraft fuel burn and save ...
# 17  Introduces a Zero Pollution Action Plan aiming...
# 18  Voting in local, national and EU elections hel...
# 19  Plans to double high-speed rail traffic by 203...
#
#                                           reference_3  \
# 0   Under the Deal, every EU policy must contribut...
# 1   The package raises the Renewable Energy Direct...
# 2   Grid modernisation and digitalisation are cent...
# 3   Choose A+++-rated appliances and run them only...
# 4   Use lids on pots and match burner sizes to coo...
# 5   They diversify the energy mix, improving secur...
# 6   Alternative-fuels infrastructure regulation wi...
# 7   Sets measures to improve animal welfare, inclu...
# 8   Share or swap rarely used goods within neighbo...
# 9   Buy second-hand goods, repair broken items and...
# 10  Restoration targets will revive 25 000 km of f...
# 11  Use beeswax wraps or reusable silicone covers ...
# 12  A dedicated Just Transition Fund of over €19 b...
# 13  Guarantee-of-origin certificates will prove th...
# 14  All new buildings must be zero-emission from 2...
# 15  Rapid turnover encourages over-consumption, cr...
# 16  Stay in eco-labelled accommodation that follow...
# 17  Strengthens urban wastewater rules to capture ...
# 18  Public-consultation feedback shapes EU regulat...
# 19  Proposes zero-emission urban logistics and car...
#
#                                           reference_4  \
# 0   A key aim is to slash emissions at least 55 % ...
# 1   By upgrading everything from fuel taxation to ...
# 2   Affordability and security of supply remain co...
# 3   Lower your thermostat by 1-2 °C and use progra...
# 4   Enable power-saving modes and unplug chargers ...
# 5   Deploying renewables creates local jobs in man...
# 6   The ReFuelEU and FuelEU proposals oblige aviat...
# 7   Encourages shorter supply chains and fairer re...
# 8   Return used products to take-back schemes so m...
# 9   Collect rainwater for gardening and install lo...
# 10  The strategy tightens rules against illegal lo...
# 11  Choose glass, metal or paper packaging over pl...
# 12  The Public Sector Loan Facility offers concess...
# 13  The TEN-E revision supports dedicated hydrogen...
# 14  Building-renovation passports will guide owner...
# 15  Buying timeless, quality pieces and mending cl...
# 16  Respect fragile ecosystems by sticking to mark...
# 17  Promotes precision farming and nutrient-manage...
# 18  Participating in citizen assemblies or climate...
# 19  Digital traffic management and multimodal tick...
#
#                                           reference_5  bleu_1  bleu_2  ...  \
# 0   The package also seeks to mobilise €1 trillion...     9.0     0.9  ...
# 1   Taken together, these new and updated laws loc...     4.0     0.3  ...
# 2   Empowering citizens—through smart meters, pros...     0.3     0.5  ...
# 3   Cut waste: repair instead of replace, recycle ...     0.3     0.6  ...
# 4   Let natural daylight in and switch to motion-s...     0.1     0.6  ...
# 5   Decentralised renewables empower communities t...     0.8     0.9  ...
# 6   Urban mobility plans encourage walking and cyc...     0.5     0.2  ...
# 7   Seeks to halve per-capita food waste at retail...     0.7     0.5  ...
# 8   Compost organic waste to cycle nutrients back ...     0.2     0.2  ...
# 9   Use renewable tariffs and switch off standby p...     0.2     0.2  ...
# 10  Agro-ecological practices and nature-based sol...     0.4     3.3  ...
# 11  Participate in local clean-up events and lobby...     0.4     0.7  ...
# 12  Technical assistance helps local authorities d...     0.1     0.1  ...
# 13  State-aid rules have been relaxed so governmen...     1.4     0.4  ...
# 14  Renovations must include EV-charging readiness...     0.3     0.3  ...
# 15  Choosing certified organic cotton or recycled ...     0.5     0.0  ...
# 16  Offset unavoidable emissions through certified...     0.1     0.1  ...
# 17  Invests in industrial decarbonisation to slash...     0.2     0.3  ...
# 18  Grassroots activism, from school strikes to co...     0.1     0.2  ...
# 19  Promotes automation and connectivity to improv...     0.2     0.2  ...
#
#     rouge1_f1_2  rouge1_f1_3  rouge1_f1_4  rouge1_f1_5  bertscore_f1  \
# 0          10.4         23.8         18.6         10.4      0.695411
# 1          13.2          8.3         11.4          6.6      0.662858
# 2          11.4          2.4          9.2          3.5      0.522448
# 3           8.5          4.3         12.4         10.6      0.536837
# 4           5.7          5.6          3.4          5.6      0.531289
# 5          11.3         15.9          6.5          6.5      0.552980
# 6           6.0          6.1          6.0          6.2      0.529699
# 7           7.2          9.1          5.5         10.8      0.529644
# 8           2.0          0.0          4.0          3.0      0.415053
# 9           7.3          3.0          1.5          5.9      0.488722
# 10         20.0          5.0          5.1          5.1      0.600564
# 11          8.8         11.4         11.6          2.9      0.535133
# 12          3.4          4.9          2.5          1.7      0.498561
# 13          6.9          7.0          4.2          1.4      0.532612
# 14          6.5          4.3          2.2          0.0      0.524445
# 15          0.0          2.0          9.6          6.1      0.509618
# 16          2.9          3.9          3.8          0.0      0.491184
# 17          8.6          3.8          5.6          5.5      0.542792
# 18          5.5          2.3          2.2          2.2      0.396752
# 19          4.1          1.4          1.4          4.2      0.513907
#
#     bertscore_ref1  bertscore_ref2  bertscore_ref3  bertscore_ref4  \
# 0         0.695411        0.545027        0.591295        0.602468
# 1         0.662858        0.537642        0.530465        0.565504
# 2         0.429814        0.517700        0.439663        0.522448
# 3         0.501377        0.536837        0.418191        0.488502
# 4         0.454937        0.531289        0.467365        0.500149
# 5         0.536290        0.529222        0.552979        0.478439
# 6         0.528174        0.474826        0.497339        0.510225
# 7         0.512044        0.485557        0.528032        0.517278
# 8         0.415053        0.392595        0.367306        0.398094
# 9         0.488722        0.451123        0.453870        0.441951
# 10        0.478792        0.600564        0.478161        0.467168
# 11        0.502472        0.512258        0.520218        0.535134
# 12        0.498561        0.450330        0.448615        0.467683
# 13        0.532612        0.459781        0.464519        0.500892
# 14        0.461955        0.524445        0.439909        0.465343
# 15        0.495523        0.459857        0.460156        0.509618
# 16        0.413936        0.455232        0.491184        0.477085
# 17        0.489381        0.542792        0.478437        0.534290
# 18        0.362570        0.396752        0.386719        0.370682
# 19        0.448330        0.426409        0.480633        0.451011
#
#     bertscore_ref5
# 0         0.548973
# 1         0.474317
# 2         0.431097
# 3         0.523224
# 4         0.440154
# 5         0.476010
# 6         0.529699
# 7         0.529644
# 8         0.388449
# 9         0.486575
# 10        0.474727
# 11        0.421335
# 12        0.436589
# 13        0.447678
# 14        0.449513
# 15        0.496130
# 16        0.453591
# 17        0.458097
# 18        0.360406
# 19        0.513907
#
# [20 rows x 34 columns]

# %%
# save as evaluation_csv.csv
df.to_csv(r"C:\Users\Nima\OneDrive - Reza Company\Desktop\Nima+\School\Datalab-V\tests\evaluation_results\evaluation_csv.csv", index=False)

df = pd.read_csv(r"C:\Users\Nima\OneDrive - Reza Company\Desktop\Nima+\School\Datalab-V\tests\evaluation_results\evaluation_csv.csv")

# %%
# Bereken hoogste BERTScore per rij
df["bertscore_max"] = df[[f"bertscore_ref{i}" for i in range(1, 6)]].max(axis=1)

# Bereken gemiddelde van hoogste scores
avg_bertscore_f1 = df["bertscore_max"].mean() *100
print("Gemiddelde BERTScore F1:", avg_bertscore_f1)
# Out:
# Gemiddelde BERTScore F1: 53.05254623293877

# %%
# Laad bestaande summary_stats
summary = pd.read_csv(r"c:\Users\Nima\OneDrive - Reza Company\Desktop\Nima+\School\Datalab-V\tests\evaluation_results\summary_stats.csv")

# Voeg nieuwe rij toe
summary = pd.concat([summary, pd.DataFrame([{
    "metric": "avg_bertscore_f1",
    "value": round(avg_bertscore_f1, 4) 
}])], ignore_index=True)


# Opslaan
summary.to_csv("summary_stats.csv", index=False)

# Controle
print(summary)
# Out:
#              metric     value
# 0       total_pairs  100.0000
# 1   avg_exact_match    0.0000
# 2  avg_word_overlap   28.7600
# 3          avg_bleu    0.4800
# 4     avg_rouge1_f1    6.5500
# 5  avg_bertscore_f1   53.0525

# %% [markdown]
# ### Conclusie van 53% BERTScore F1:
#
# Het model scoort gemiddeld 53% semantische overeenkomst met de beste referentie per vraag.
#
# Dit betekent dat meer dan de helft van de betekenis van het referentieantwoord wordt overgebracht, zelfs als exacte woorden verschillen.
#
# Dit toont aan dat het model inhoudelijk nuttige en relevante antwoorden kan geven, ook als het afwijkt van de oorspronkelijke
# formulering.
